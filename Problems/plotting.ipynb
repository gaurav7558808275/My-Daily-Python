# %%
import pandas as pd
import numpy as np
import matplitlib.pyplot as plt
from sklearn import linear_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-88771c891249> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplitlib.pyplot as plt
#       4 from sklearn import linear_model
#
# ModuleNotFoundError: No module named 'matplitlib'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
#scikitlearn library contains all the models

# %%
data = {'Area' : [2500,3000,3200,3500] , 'Price':[1000,2000,2500,3000]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Area  Price
# 0  2500   1000
# 1  3000   2000
# 2  3200   2500
# 3  3500   3000

# %%
df.
